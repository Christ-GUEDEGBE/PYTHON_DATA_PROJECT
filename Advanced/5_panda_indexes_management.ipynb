# %%
# Importing librairies
import matplotlib.pyplot as plt
import pandas as pd
from datasets import load_dataset

# Loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = pd.DataFrame(dataset['train'])

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# Testing sort_values, sort_indexes, reset_index, set_index methods...

# %%
df_5=df.pivot_table(index='job_title_short',
                    values='salary_year_avg',
                    aggfunc=['min', 'max', 'median'])

# %%
df_5.sort_index(inplace=False)
df_5
# Out:
#                                       min             max          median
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  16500.0        387460.0         85000.0
# Cloud Engineer                    42000.0        280000.0         90000.0
# Data Analyst                      25000.0        650000.0         90000.0
# Data Engineer                     15000.0        525000.0        125000.0
# Data Scientist                    27000.0        960000.0        127500.0
# Machine Learning Engineer         30000.0        325000.0        106415.0
# Senior Data Analyst               30000.0        425000.0        111175.0
# Senior Data Engineer              35000.0        425000.0        147500.0
# Senior Data Scientist             45000.0        890000.0        155500.0
# Software Engineer                 28000.0        375000.0         99150.0

# %%
df_pay=df.copy()
df_pay=df_pay.dropna(subset='salary_year_avg').reset_index()
df_pay.index.name='nomen'
df_pay
# Out:
#         index job_title_short  \
# nomen
# 0          28  Data Scientist
# 1          77   Data Engineer
# 2          92   Data Engineer
# 3         100  Data Scientist
# 4         109    Data Analyst
# ...       ...             ...
# 21998  785624   Data Engineer
# 21999  785641   Data Engineer
# 22000  785648  Data Scientist
# 22001  785682  Data Scientist
# 22002  785692  Data Scientist
#
#                                                job_title  \
# nomen
# 0                                    CRM Data Specialist
# 1                                          Data Engineer
# 2                Remote - Data Engineer - Permanent - W2
# 3                Data Scientist, Risk Data Mining - USDS
# 4                  Senior Supply Chain Analytics Analyst
# ...                                                  ...
# 21998                   Data Analytics Engineer (Hybrid)
# 21999                                      Data Engineer
# 22000  Director Data Scientist - Commercial Platforms...
# ...
